# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# display all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# normalizes data and prettify in dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10686
# 1    1027     Ethereum    ETH      ethereum              8113
# 2     825  Tether USDt   USDT        tether             69728
# 3    5426       Solana    SOL        solana               563
# 4    1839          BNB    BNB           bnb              1922
# 5      52          XRP    XRP           xrp              1190
# 6    3408         USDC   USDC      usd-coin             15782
# 7    2010      Cardano    ADA       cardano              1011
# 8    5805    Avalanche   AVAX     avalanche               618
# 9      74     Dogecoin   DOGE      dogecoin               861
# 10   6636     Polkadot    DOT  polkadot-new               653
# 11   1958         TRON    TRX          tron               893
# 12   3890      Polygon  MATIC       polygon              1196
# 13   1975    Chainlink   LINK     chainlink              1532
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    # put in dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df
    df_append = pd.DataFrame(df2)
    df = pd.concat([df2,df_append])
    
    
    # create csv
    #if not os.path.isfile(r'C:\Users\Administration\Desktop\Alex Data Analyst Boot Camp\Python\python project\pythonAPI.csv'):
     #   df.to_csv(r'C:\Users\Administration\Desktop\Alex Data Analyst Boot Camp\Python\python project\pythonAPI.csv', header='column_names')
    #else:
     #   df.to_csv(r'C:\Users\Administration\Desktop\Alex Data Analyst Boot Camp\Python\python project\pythonAPI.csv', mode='a', header=False)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed!')
    sleep(60) #run every minute
exit()
# Out:
# API Runner completed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       6     api_runner()
#       7     print('API Runner completed!')
# ----> 8     sleep(60) #run every minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'C:\Users\Administration\Desktop\Alex Data Analyst Boot Camp\Python\python project\pythonAPI.csv')
df72
# Out:
#     Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0            0      1      Bitcoin    BTC       bitcoin             10686
# 1            1   1027     Ethereum    ETH      ethereum              8113
# 2            2    825  Tether USDt   USDT        tether             69728
# 3            3   5426       Solana    SOL        solana               563
# 4            4   1839          BNB    BNB           bnb              1922
# 5            5     52          XRP    XRP           xrp              1190
# 6            6   3408         USDC   USDC      usd-coin             15781
# 7            7   2010      Cardano    ADA       cardano              1011
# 8            8   5805    Avalanche   AVAX     avalanche               618
# 9            9     74     Dogecoin   DOGE      dogecoin               861
# 10          10   6636     Polkadot    DOT  polkadot-new               653
# 11          11   1958         TRON    TRX          tron               893
# ...

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10686
# 1    1027     Ethereum    ETH      ethereum              8113
# 2     825  Tether USDt   USDT        tether             69728
# 3    5426       Solana    SOL        solana               563
# 4    1839          BNB    BNB           bnb              1922
# 5      52          XRP    XRP           xrp              1190
# 6    3408         USDC   USDC      usd-coin             15782
# 7    2010      Cardano    ADA       cardano              1011
# 8    5805    Avalanche   AVAX     avalanche               618
# 9      74     Dogecoin   DOGE      dogecoin               861
# 10   6636     Polkadot    DOT  polkadot-new               653
# 11   1958         TRON    TRX          tron               893
# 12   3890      Polygon  MATIC       polygon              1196
# 13   1975    Chainlink   LINK     chainlink              1532
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10686
# 1    1027     Ethereum    ETH      ethereum              8113
# 2     825  Tether USDt   USDT        tether             69728
# 3    5426       Solana    SOL        solana               563
# 4    1839          BNB    BNB           bnb              1922
# 5      52          XRP    XRP           xrp              1190
# 6    3408         USDC   USDC      usd-coin             15782
# 7    2010      Cardano    ADA       cardano              1011
# 8    5805    Avalanche   AVAX     avalanche               618
# 9      74     Dogecoin   DOGE      dogecoin               861
# 10   6636     Polkadot    DOT  polkadot-new               653
# 11   1958         TRON    TRX          tron               893
# 12   3890      Polygon  MATIC       polygon              1196
# 13   1975    Chainlink   LINK     chainlink              1532
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -1.13271                      -3.99900
# Ethereum                        -1.43401                      -3.80454
# Tether USDt                     -0.01190                      -0.07306
# Solana                          -5.44943                     -14.56448
# BNB                             -1.94771                       9.43372
# XRP                             -2.02601                      -3.69187
# USDC                            -0.00812                      -0.05224
# Cardano                         -4.76446                      -6.69170
# Avalanche                       -4.46952                      -9.94258
# Dogecoin                        -2.84405                      -4.72853
# Polkadot                        -3.53897                      -7.04613
# TRON                            -1.43022                      -3.70018
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -1.13271
#              quote.USD.percent_change_24h    -3.99900
#              quote.USD.percent_change_7d     -0.34062
#              quote.USD.percent_change_30d    12.18735
#              quote.USD.percent_change_60d    24.32177
#              quote.USD.percent_change_90d    59.51521
# Ethereum     quote.USD.percent_change_1h     -1.43401
#              quote.USD.percent_change_24h    -3.80454
#              quote.USD.percent_change_7d      2.12578
#              quote.USD.percent_change_30d     6.92733
#              quote.USD.percent_change_60d    24.38583
#              quote.USD.percent_change_90d    37.37469
# Tether USDt  quote.USD.percent_change_1h     -0.01190
#              quote.USD.percent_change_24h    -0.07306
#              quote.USD.percent_change_7d     -0.00309
#              quote.USD.percent_change_30d    -0.01142
#              quote.USD.percent_change_60d    -0.05764
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -1.13271
#             quote.USD.percent_change_24h  -3.99900
#             quote.USD.percent_change_7d   -0.34062
#             quote.USD.percent_change_30d  12.18735
#             quote.USD.percent_change_60d  24.32177
#             quote.USD.percent_change_90d  59.51521
# Ethereum    quote.USD.percent_change_1h   -1.43401
#             quote.USD.percent_change_24h  -3.80454
#             quote.USD.percent_change_7d    2.12578
#             quote.USD.percent_change_30d   6.92733
#             quote.USD.percent_change_60d  24.38583
#             quote.USD.percent_change_90d  37.37469
# Tether USDt quote.USD.percent_change_1h   -0.01190
#             quote.USD.percent_change_24h  -0.07306
#             quote.USD.percent_change_7d   -0.00309
#             quote.USD.percent_change_30d  -0.01142
#             quote.USD.percent_change_60d  -0.05764
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.set_index(index)
df6
# Out:
#       values
# 0   -1.13271
# 1   -3.99900
# 2   -0.34062
# 3   12.18735
# 4   24.32177
# 5   59.51521
# 6   -1.43401
# 7   -3.80454
# 8    2.12578
# 9    6.92733
# 10  24.38583
# 11  37.37469
# 12  -0.01190
# 13  -0.07306
# 14  -0.00309
# 15  -0.01142
# 16  -0.05764
# 17   0.03787
# 18  -5.44943
# 19 -14.56448
# 20  45.44826
# 21  85.91133
# 22 231.05421
# 23 459.43782
# 24  -1.94771
# 25   9.43372
# 26  15.04452
# 27  26.40362
# 28  29.96545
# 29  37.44284
# 30  -2.02601
# 31  -3.69187
# 32   1.79830
# 33  -0.91093
# 34  12.42013
# 35  21.50203
# 36  -0.00812
# 37  -0.05224
# 38  -0.03395
# 39   0.05630
# 40  -0.02192
# 41  -0.01580
# 42  -4.76446
# 43  -6.69170
# 44   1.11144
# 45  51.52375
# 46 102.53470
# 47 138.54747
# 48  -4.46952
# 49  -9.94258
# 50   9.86641
# 51 110.60312
# 52 308.81353
# 53 385.95524
# 54  -2.84405
# 55  -4.72853
# 56  -0.57768
# 57  16.81532
# 58  30.68380
# 59  48.17156
# 60  -3.53897
# 61  -7.04613
# 62  27.76983
# 63  63.32571
# 64 107.07412
# ...

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'perc_chng'})
df7
# Out:
#       values
# 0   -1.13271
# 1   -3.99900
# 2   -0.34062
# 3   12.18735
# 4   24.32177
# 5   59.51521
# 6   -1.43401
# 7   -3.80454
# 8    2.12578
# 9    6.92733
# 10  24.38583
# 11  37.37469
# 12  -0.01190
# 13  -0.07306
# 14  -0.00309
# 15  -0.01142
# 16  -0.05764
# 17   0.03787
# 18  -5.44943
# 19 -14.56448
# 20  45.44826
# 21  85.91133
# 22 231.05421
# 23 459.43782
# 24  -1.94771
# 25   9.43372
# 26  15.04452
# 27  26.40362
# 28  29.96545
# 29  37.44284
# 30  -2.02601
# 31  -3.69187
# 32   1.79830
# 33  -0.91093
# 34  12.42013
# 35  21.50203
# 36  -0.00812
# 37  -0.05224
# 38  -0.03395
# 39   0.05630
# 40  -0.02192
# 41  -0.01580
# 42  -4.76446
# 43  -6.69170
# 44   1.11144
# 45  51.52375
# 46 102.53470
# 47 138.54747
# 48  -4.46952
# 49  -9.94258
# 50   9.86641
# 51 110.60312
# 52 308.81353
# 53 385.95524
# 54  -2.84405
# 55  -4.72853
# 56  -0.57768
# 57  16.81532
# 58  30.68380
# 59  48.17156
# 60  -3.53897
# 61  -7.04613
# 62  27.76983
# 63  63.32571
# 64 107.07412
# ...

# %%
#df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
#df7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='perc_chng', y='values', hue='name', data=df7, kind='point')

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
